# %%
import sys 
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import operator
print(operator.mul(10,5))
print(operator.sub(10,5))
print(operator.add(10,5))
# Out:
# 50
# 5
# 15

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\laxma

# %%
import operator
print(operator.mul(10,5))
# Out:
# 50

# %%
#single line statements
p1=['a'+'b'+'c'+'d']
print(p1)
# Out:
# ['abcd']

# %%
#multi line statements
p1=20+30 \
+40+50\
+60
print(p1)
# Out:
# 200

# %%
#string creation 
str1="python"
print(str1)
# Out:
# python

# %%
str2="HELLO PYTHON"
print(str2)
print(str2[5])
# Out:
# HELLO PYTHON

# %%
str3="I LOVE PYTHON"
print(str3[7])
print(str3[1])#printing space
print(str3[6])
# Out:
# P

# %%
str2=str2.replace('HE','HI')
print(str2)
# Out:
# HILLO PYTHON

# %%
str4="RCK"
str4=str4.replace('K','B')
print(str4)
# Out:
# RCB

# %%
#string concatenation
str5="data"
str6="Science"
str7=str5+ " "+str6
print(str7)

s1="Hello"
s2="Everyone"
s3=s1+ " "+s2
print(s3)
# Out:
# data Science
# Hello Everyone

# %%
#string membership
str8="HELLO PYTHON"
print("HELLO" in str8)
print("SCIENCE" not in str8)
# Out:
# True
# True

# %%
str8="KANTARA CHAPTER 1"
print("KANTARA" in str8)
print("CHAPTER" not in str8)
print("1" in str8)
# Out:
# True
# False
# True

# %%
#string partioning
string="This is a separator of this line"
print(string.partition("separator"))
# Out:
# ('This is a ', 'separator', ' of this line')

# %%
str1="HELLO PYTHON"
print(str1[0:5])
print(str1[6:])
# Out:
# HELLO
# PYTHON

# %%
str1="I AM IRONMAN"
print(str1[5:9])
print(str1[-7:-3])#NEGATIVE INDEXING
# Out:
# IRON
# IRON

# %%
str2="HELLO PYTHON"
print(str2[::-1])#reversing the string
print(str2[0::2])
# Out:
# NOHTYP OLLEH
# HLOPTO

# %% [markdown]
# **STRING FUNCTIONS**

# %%
#count function
str1="Banana"
print(str1.count('a'))
print(str1.count('n'))
#strip function
text2=" HELLO "
print(text2.rstrip())#removes right space
print(text2.lstrip())#removes left space

text2="***HELLO***"
print(text2.strip("*"))#removes specific character given in the bracket
# Out:
# 3
# 2
#  HELLO
# HELLO
# HELLO

# %%
text3="kantara"
print(text3.upper())
text4="LUCKY"
print(text4.lower())
# Out:
# KANTARA
# lucky

# %%
text4="HELLO PYTHON"
print(text4.startswith("HELLO"))
print(text4.endswith("PYTHN"))
print(text4.endswith("PYTHON"))
# Out:
# True
# False
# True

# %%
#split function
text5="I LOVE PYTHON"
print(text5.split()) #splits our string into list
# Out:
# ['I', 'LOVE', 'PYTHON']

# %% [markdown]
# **TYPECASTING**

# %%
#Auto typecasting
val=6+5.0+True
print(val)
#forced typecasting
print(int(val))
# Out:
# 12.0
# 12
